# %%
# !pip install openai
# Out:
# ...
#   Using cached openai-2.30.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached jiter-0.13.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
# Using cached openai-2.30.0-py3-none-any.whl (1.1 MB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jiter-0.13.0-cp313-cp313-macosx_11_0_arm64.whl (317 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [openai]2m6/7 [openai]
# ...

# %%
from openai import OpenAI

KEY = '5e959805976f26da331130c389e26aca02e8ea6f33515c1d4021b7cf6aede434'
URL = "http://hvdemo.mlsa-iai.ru:30000/v1"

oclient = OpenAI(api_key=KEY, base_url= URL)
for mod in oclient.models.list().data:
    print(mod)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 URL = "http://hvdemo.mlsa-iai.ru:30000/v1"
#       6 oclient = OpenAI(api_key=KEY, base_url= URL)
# ----> 7 for mod in oclient.models.list().data:
#       8     print(mod)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages/openai/resources/models.py:94, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      80 def list(
#      81     self,
#      82     *,
#    (...)     88     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      89 ) -> SyncPage[Model]:
#      90     """
#      91     Lists the currently available models, and provides basic information about each
#      92     one such as the owner and availability.
#      93     """
# ---> 94     return self._get_api_list(
#      95         "/models",
# ...
